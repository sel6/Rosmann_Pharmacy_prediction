# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
import pandas as pd
import numpy as np
import warnings
import sys
import scipy.stats as scs
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
sys.path.insert(0, '../scripts')
from vizualisation import Data_Viz
from cleaning import DataCleaner
from transformation import DataTransformer
from sklearn.ensemble import RandomForestRegressor

# %%
warnings.filterwarnings('ignore')
sys.path.insert(0, '../scripts')
dv= Data_Viz()
dc = DataCleaner()
dt = DataTransformer()

# %%
# importing datasets
sample_df = pd.read_csv("../data/sample_submission.csv")
store_df = pd.read_csv("../data/store.csv")
test_df = pd.read_csv("../data/test.csv")
train_df = pd.read_csv("../data/train.csv")
features_df = pd.read_csv("../data/features.csv")

# %%
features_df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
features_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType  ... Promo2SinceYear  \
# 0                  0              1         c  ...             0.0
# 1                  0              1         a  ...          2010.0
# 2                  0              1         a  ...          2011.0
# 3                  0              1         c  ...             0.0
# 4                  0              1         a  ...             0.0
# ...              ...            ...       ...  ...             ...
# 1017204            a              1         a  ...          2013.0
# 1017205            a              1         c  ...             0.0
# 1017206            a              1         a  ...             0.0
# 1017207            a              1         a  ...             0.0
# 1017208            a              1         d  ...          2012.0
#
#             PromoInterval  Holiday  Year  Month DayOfMonth  WeekOfYear  \
# 0                       -        0  2015      7         31          31
# 1         Jan,Apr,Jul,Oct        0  2015      7         31          31
# 2         Jan,Apr,Jul,Oct        0  2015      7         31          31
# 3                       -        0  2015      7         31          31
# 4                       -        0  2015      7         31          31
# ...                   ...      ...   ...    ...        ...         ...
# 1017204   Jan,Apr,Jul,Oct        1  2013      1          1           1
# 1017205                 -        1  2013      1          1           1
# 1017206                 -        1  2013      1          1           1
# 1017207                 -        1  2013      1          1           1
# 1017208  Mar,Jun,Sept,Dec        1  2013      1          1           1
#
#          weekday  month_season  year_season
# 0              1             2            2
# 1              1             2            2
# 2              1             2            2
# 3              1             2            2
# 4              1             2            2
# ...          ...           ...          ...
# 1017204        1             0            0
# 1017205        1             0            0
# 1017206        1             0            0
# 1017207        1             0            0
# 1017208        1             0            0
#
# [1017209 rows x 24 columns]

# %%
#identify catagorical and numerical
dt.catagory(features_df)
# Out:
# Numerical Columns: ['Store', 'DayOfWeek', 'Sales', 'Customers', 'Open', 'Promo', 'SchoolHoliday', 'CompetitionDistance', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'Holiday', 'Year', 'Month', 'DayOfMonth', 'WeekOfYear', 'weekday', 'month_season', 'year_season']
# ****************
# Categorical Columns: ['Date', 'StateHoliday', 'StoreType', 'Assortment', 'PromoInterval']

# %%
#stateholiday hav mixed data types so let's change them to string
dc.replace_rows_str(features_df, "StateHoliday")
# Out:
# Index(['0', 'a', 'b', 'c'], dtype='object')

# %%
#i took sample because the size of my model become too big to save
sample_feature = features_df.sample(n=300000)

# %%
#label, scale, spearate target featues, split and the add the steps in pipeline
pipe = Pipeline(steps = [
                        ("labele", FunctionTransformer(dt.cat_labeler, kw_args={"cat_cols": ['Date', 'StateHoliday', 'StoreType', 'Assortment', 'PromoInterval']})),
                        ("scale", FunctionTransformer(dt.scaler)), 
                        ("target_feature", FunctionTransformer(dt.target_feature, kw_args={"f_r":1, "t":0})),
                        ("split", FunctionTransformer(dt.set_splitter, kw_args={"test": 0.1, "val":0.2, "rand_state":8}))
                        ])

P = pipe.fit_transform(sample_feature)

# %%
#random forest regressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
 
# fit the regressor with x_train, y_train data
regressor.fit(P[0], P[1])
# Out:
# RandomForestRegressor(random_state=0)

# %%
import pickle
filename = "../models/random_forest.pkl"
pickle.dump(regressor, open(filename, 'wb'))

# %%
#let's check if the accuracy is affected on the sampled data
Y_pred = regressor.score(P[2], P[3])
Y_pred
# Out:
# 0.9783567577907746

# %% [markdown]
# * for loss function i'll be using MSE=Mean Squared Error
# 1. because I can use it for a dataset that has no outlier
# 2. it penalises large errors
# 3. it's easy to calculate gradient with MSE

# %%
sample_feature
# Out:
#            Store  DayOfWeek      Date     Sales  Customers  Open  Promo  \
# 746721  0.409336   0.833333  0.257173  0.106659   0.071468   1.0    0.0
# 39661   0.570916   0.666667  0.962806  0.208928   0.120290   1.0    0.0
# 420107  0.482047   0.666667  0.568544  0.115388   0.112307   1.0    1.0
# 759617  0.975763   0.166667  0.245484  0.094014   0.072211   1.0    0.0
# 262674  0.124776   0.333333  0.744952  0.246655   0.208650   1.0    1.0
# ...          ...        ...       ...       ...        ...   ...    ...
# 266666  0.393178   0.833333  0.740701  0.207403   0.168368   1.0    0.0
# 286970  0.106822   0.666667  0.717322  0.213739   0.129386   1.0    1.0
# 682482  0.796230   0.000000  0.318810  0.089939   0.068313   1.0    0.0
# 217660  0.210952   0.833333  0.792774  0.126955   0.108966   1.0    0.0
# 488071  0.436266   1.000000  0.503719  0.000000   0.000000   0.0    0.0
#
#         StateHoliday  SchoolHoliday  StoreType  ...  Promo2SinceYear  \
# 746721           0.0            0.0        1.0  ...         0.999007
# 39661            0.0            0.0        1.0  ...         0.997022
# 420107           0.0            0.0        0.0  ...         0.000000
# 759617           0.0            1.0        0.0  ...         0.999007
# 262674           0.0            0.0        0.0  ...         0.999007
# ...              ...            ...        ...  ...              ...
# 266666           0.0            0.0        0.0  ...         0.000000
# 286970           0.0            0.0        1.0  ...         0.997022
# 682482           0.0            0.0        1.0  ...         0.998511
# 217660           0.0            0.0        0.0  ...         0.000000
# 488071           0.0            0.0        1.0  ...         0.998511
#
#         PromoInterval  Holiday  Year     Month  DayOfMonth  WeekOfYear  \
# 746721       0.666667      0.0   0.0  0.636364    1.000000    0.666667
# 39661        0.333333      0.0   1.0  0.454545    0.833333    0.490196
# 420107       0.000000      0.0   0.5  0.454545    0.633333    0.470588
# 759617       0.666667      0.0   0.0  0.636364    0.633333    0.647059
# 262674       0.666667      0.0   0.5  1.000000    0.066667    0.941176
# ...               ...      ...   ...       ...         ...         ...
# 266666       0.000000      0.0   0.5  0.909091    0.933333    0.921569
# 286970       0.666667      0.0   0.5  0.909091    0.200000    0.862745
# 682482       1.000000      0.0   0.0  0.818182    0.900000    0.843137
# 217660       0.000000      0.0   1.0  0.000000    0.533333    0.039216
# 488071       0.666667      0.0   0.5  0.272727    0.633333    0.294118
#
#         weekday  month_season  year_season
# 746721      0.0           1.0     0.666667
# 39661       1.0           1.0     0.333333
# 420107      1.0           0.5     0.333333
# 759617      1.0           0.5     0.666667
# 262674      1.0           0.0     1.000000
# ...         ...           ...          ...
# 266666      0.0           1.0     1.000000
# 286970      1.0           0.0     1.000000
# 682482      1.0           1.0     1.000000
# 217660      0.0           0.5     0.000000
# 488071      0.0           0.5     0.333333
#
# [300000 rows x 24 columns]

# %%
feat_imp =[]
for i in sample_feature.columns.to_list():
    if i!='Sales':
        feat_imp.append(i)

plt.barh(feat_imp, regressor.feature_importances_)
# Out:
# <BarContainer object of 23 artists>

# %% [markdown]
# * from the feature importance plot:
#     * Competition Distance is the highest contributor for sales, followed by Promo2SinceWeek
